# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 4
#
# ## О документе
#
# Версия 1.03
#
# Модуль 4 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 4. Следование по трассе с киберпрепятствиями
#
# Для успешного выполнения этого задания необходимое активировать специальный режим работы виртуальной машинки - в рамках этого задания можно менять только блоки, отвечающие за безопасность (ограничитель, монитор безопасности), **другие блоки менять запрещено**.
#
# При прохождении маршрута будут имитироваться атаки со стороны злоумышленников, которые будут пытаться нарушить цели безопасности. Важно, чтобы им это не удалось.

# %% [markdown]
# 1. Запустите свою машинку и убедитесь, что она проходит всю трассу без нарушений ограничений скорости. При необходимости измените логику работы блока безопасности
# 2. Добавьте контроль доставки груза в модуле SafetyBlock - убедитесь, что груз доставляется до конечной точки маршрута.
# 3. Если в модуле 3 вы реализовали монитор безопасности - не забудьте его перенести в этот модуль, это принесёт дополнительные баллы!

# %% [markdown]
# Активация киберпрепятствий в системе управления:
#
# после инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# В этом блоке добавьте все ваши реализации изменённых бортовых систем

# %%
# ваш код

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m4"

# %% [markdown]
# В следующем блоке измените маршрут на ваш, его можно скопировать из модуля 2.
#
# Для проверки работы систем безопасности будут активированы киберпрепятствия
#
# ```python
# control_system.enable_surprises()
# ```

# %%
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep

from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser
from src.mission_type import GeoSpecificSpeedLimit


# для примера возьмём маршрут из модуля 2
# следует заменить на маршрут, требуемый по регламенту!
wpl_file = "module2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()

# обновите скоростные ограничения для вашего маршрута!
speed_limits = [
    GeoSpecificSpeedLimit(0, 30),
    GeoSpecificSpeedLimit(1, 60),
    GeoSpecificSpeedLimit(5, 20),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 


# создание блоков передачи данных в СУПА
if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

# создание основных функциональных блоков
mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)


# сборка всех запускаемых блоков в одном "кузове"
system_components = SystemComponentsContainer(
    components=[
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

# запуск всех блоков
system_components.start()

# ограничение поездки по времени
# в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# при условии, что повторный запуск закончился успешно
sleep(100)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 10:30:34.262205
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][CONTROL] новая скорость 30 (была 0)
# [ИНФО][CONTROL] новое направление 251 (было 0)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 30)
# [ИНФО][CONTROL] новое направление 142 (было 251)
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 142.15592535488207, расчётное 322.1559253548821
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 142.5982455662425, расчётное 322.5982455662425
# [ИНФО][CONTROL] новое направление 143 (было 142)
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.04282516926833, расчётное 323.0428251692683
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.48955414368152, расчётное 323.4895541436815
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.5109901805705, расчётное 323.5109901805705
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.52563963415793, расчётное 323.5256396341579
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.53311040656843, расчётное 323.5331104065684
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.53298506557144, расчётное 323.53298506557144
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.53247266217073, расчётное 323.53247266217073
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.5316757799535, расчётное 323.5316757799535
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.5307119140549, расчётное 323.5307119140549
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.52971536434848, расчётное 323.5297153643485
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.52869170596074, расчётное 323.52869170596074
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.52764493490008, расчётное 323.5276449349001
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.5265770100421, расчётное 323.5265770100421
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.52548730038063, расчётное 323.52548730038063
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.52437500552242, расчётное 323.5243750055224
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.52323917148874, расчётное 323.52323917148874
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.5221024978295, расчётное 323.5221024978295
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.52094160807775, расчётное 323.52094160807775
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.51975538003535, расчётное 323.51975538003535
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.51854205767376, расчётное 323.51854205767376
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.51730027503413, расчётное 323.51730027503413
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.51602856036277, расчётное 323.51602856036277
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.51472533794225, расчётное 323.51472533794225
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.5133889046367, расчётное 323.5133889046367
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.51201741570281, расчётное 323.5120174157028
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.51060886948596, расчётное 323.51060886948596
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.5091610877417, расчётное 323.5091610877417
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.50767169452115, расчётное 323.50767169452115
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.50613809244652, расчётное 323.5061380924465
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.50455743383048, расчётное 323.5045574338305
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.50292658640012, расчётное 323.5029265864001
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.50125235606237, расчётное 323.50125235606237
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.49986815238202, расчётное 323.499868152382
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.49808908995266, расчётное 323.49808908995266
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.49624545344045, расчётное 323.49624545344045
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.494319330189, расчётное 323.494319330189
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.49231638216997, расчётное 323.49231638217
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.49022997127418, расчётное 323.4902299712742
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.48805309992758, расчётное 323.4880530999276
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.48577730561038, расчётное 323.4857773056104
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.48339289050426, расчётное 323.48339289050426
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.4808886422221, расчётное 323.4808886422221
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.4782515263032, расчётное 323.4782515263032
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.47546627658198, расчётное 323.475466276582
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.47251485598815, расчётное 323.47251485598815
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.46937574960714, расчётное 323.46937574960714
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.46602301520488, расчётное 323.4660230152049
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.46242499482372, расчётное 323.4624249948237
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.45854251994518, расчётное 323.4585425199452
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.45432636299995, расчётное 323.45432636299995
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.44971351819817, расчётное 323.44971351819817
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.44462162746925, расчётное 323.44462162746925
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.43894029907182, расчётное 323.4389402990718
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.43251706507482, расчётное 323.4325170650748
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.42513348856698, расчётное 323.425133488567
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.41646203486619, расчётное 323.4164620348662
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.4059821270268, расчётное 323.4059821270268
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.39280018711895, расчётное 323.39280018711895
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.3752103647903, расчётное 323.3752103647903
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.3494038969876, расчётное 323.3494038969876
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.30439145234357, расчётное 323.30439145234357
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.18681800468482, расчётное 323.1868180046848
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 160 (была 60)
# [ИНФО][CONTROL] новое направление 232 (было 143)
# [ИНФО][SAFETY] сегмент пройден
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][CONTROL] новое направление 229 (было 232)
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][CONTROL] новое направление 227 (было 229)
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][CONTROL] новое направление 226 (было 227)
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][CONTROL] новое направление 227 (было 226)
# [ОШИБКА][SAFETY] принудительное ограничение скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 160)
# [ИНФО][CONTROL] новое направление 231 (было 227)
# [ИНФО][SAFETY] сегмент пройден
# [ОШИБКА][SAFETY] попытка сброса груза до завершения маршрута
# [ИНФО][CONTROL] новое направление 232 (было 231)
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 330 (было 232)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 335 (было 330)
# [ИНФО][CONTROL] новое направление 339 (было 335)
# [ИНФО][CONTROL] новое направление 340 (было 339)
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 60)
# [ИНФО][CONTROL] новое направление 237 (было 340)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 222 (было 237)
# [ИНФО][CONTROL] новое направление 209 (было 222)
# [ИНФО][CONTROL] новое направление 207 (было 209)
# [ИНФО][CONTROL] новое направление 206 (было 207)
# [ИНФО][CONTROL] новое направление 205 (было 206)
# [ИНФО][CONTROL] маршрут пройден, текущее время 10:32:08.487030
# [ИНФО][CONTROL] новая скорость 0.0 (была 20)
# [ИНФО][CONTROL] новое направление 0 (было 205)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# Убедитесь, что
# 1. ваша машинка успешно прошла весь заданный маршрут
# 2. не превысила ограничения скорости
# 3. успешно доставила груз
#
# Если всё так - поздравляем, вы справились с заданием! Обязательно зафиксируйте все изменения в репозитории!

# %% [markdown]
# Мы будем признательны за обратную связь - любые комментарии, которые вы можете дать по итогам выполнения этого задания.
#
# Например,
#
# - было ли задание понятным по шкале 1..10 (1 - ничего не понятно, 10 - вопросов вообще не было, всё понятно)?
# - было ли задание интересным по шкале 1..10 (1 - скука смертная, 10 - лучшее, что вам пока встречалось на олимпиадах)?
# - что бы вы предложили изменить, чтобы сделает его более интересным?
# - по шкале 1..10 насколько сложным оно было для вас?
# - что было самым трудным в задании?
#
# Авторы наиболее развёрнутых и интересных комментариев получат особенный приз от Лаборатории Касперского!

# %% [markdown]
# Дополнительная информация о кибериммунной разработке
# - https://os.kaspersky.ru/cyber-immune-development/
# - https://github.com/sergey-sobolev/cyberimmune-systems/wiki/%D0%9A%D0%B8%D0%B1%D0%B5%D1%80%D0%B8%D0%BC%D0%BC%D1%83%D0%BD%D0%B8%D1%82%D0%B5%D1%82
# - канал в телеграм: https://t.me/learning_cyberimmunity
